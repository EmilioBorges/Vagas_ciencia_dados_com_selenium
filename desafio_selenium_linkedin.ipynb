# %%
#Instalação Selenium
# !pip install selenium

# %%
#import libs
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
#definicao da Janela
chrome_options = Options()
chrome_options.add_argument("--incognito")
chrome_options.add_argument("--window-size=1920x1080")

# %%
driver = webdriver.Chrome(chrome_options=chrome_options)
# Out:
# <ipython-input-4-1ff49423c34f>:1: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)

# %%
url = "https://br.linkedin.com/jobs/ci%C3%AAncia-de-dados-vagas?position=1&pageNum=0"
driver.get(url)
time.sleep(2)

# %%
result = driver.find_element_by_xpath('//*[@id="main-content"]')

# %%
title_results = result.find_elements_by_css_selector('.base-search-card__title')

# %%
product_list = [el.text for el in title_results]

# %%
for i in range (len(product_list)):
    print(product_list[i])
# Out:
# Analista Ciência de Dados PL / SR
# Especialista Ciência de dados
# Consultor Ciência de Dados
# Estagiário(a) - Ciência de Dados
# Coordenador Ciência de Dados | Pricing
# Gerente de Ciência de Dados
# Especialista em Ciência de Dados - IT Data Analytics
# Estagiário(a) - Ciência de Dados
# Pessoa Coordenadora de Ciência de Dados
# Cientista de dados
# Analista Ciência de Dados Sênior | Pricing
# Analista de Privacidade de Dados
# Cientista de dados Junior
# Estagiário em Ciência de Dados e Sistemas de informação
# Gerente de ciência de dados
# TI - ANALISTA DE REDES
# Coordenador de Ciência de Dados
# Banco de Talentos - Cientista de Dados
# Programa Summer Acadêmico 2022
# Estágio em Ciência de Dados - Macroeconomia
# Analista de Dados Júnior, Time de Fraude
# Especialista de Gestão da Informação - Ciência de Dados | REALIZE
# Especialista de Ciência de Dados
# Cientista de Dados - Junior/Pleno
# Bolsista

# %%
# a = 2
# print(a)
# print('este e o valor de {}'.format(a))
# print(f'este e o valor de {a}')

# %%
 #i = 4
# for x in range(1, i+1, 2):
#     print(x)

# %%
# lista_aux = []
# lista_aux.append(35)
# lista_aux.append([10, 20, 30])

# %%
# lista_aux[0]
# Out:
# 35

# %%
url = "https://br.linkedin.com/jobs/ci%C3%AAncia-de-dados-vagas?position=0&pageNum=0"
driver.get(url)
descr_list = []
for x in range(i+1):
    #print(x)  
    opt = product_list[x]
    print(opt)
    title_seach = driver.find_element_by_xpath(f'//*[@id="main-content"]/section[2]/ul/li[{x+1}]')
    time.sleep(5)
    title_seach.click()
    time.sleep(5)
    
    #pega descricao
    teste = driver.find_element_by_xpath('//*[@id="main-content"]/section[1]/div/div[1]/section[1]/div/div/section').text
    #print(teste)
    descr_list.append(teste)
    #teste2 = [teste]
    
    time.sleep(3)
    print(descr_list)
    driver.get(url)
#descr_list = [el.text for el in teste2]
    #time.sleep(5)
     
print(product_list[x])
#print(descr_list)
# Out:
# Analista Ciência de Dados PL / SR
# ['Buscamos profissionais que acreditam no valor e na capacidade de desenvolvimento das pessoas, almejem crescimento pessoal e profissional, aproveitem oportunidades para superar desafios e respeitem a diversidade do ser humano.\n\nSe você possui um perfil arrojado, inovador, e está sempre em busca de novos desafios, esta oportunidade é para você!\n\n\n\n\n\n\n\n\n\n\n\n\n\nExibir mais']
# Especialista Ciência de dados
# ...

# %%
pd.DataFrame({'Descricao':descr_list})
# Out:
#                                             Descricao
# 0   Buscamos profissionais que acreditam no valor ...
# 1   Se você é descomplicado, apaixonado por pet, p...
# 2   Qual será seu desafio aqui?\nLiderar um time d...
# 3   Aqui na Nelogica, desenvolvemos soluções para ...
# 4   Atividades:\n\nResponsável pela gestão dos ana...
# 5   Job Description\n\nAs one of the major healthc...
# 6   A EY é líder global em serviços de Auditoria, ...
# 7   Aqui na Nelogica, desenvolvemos soluções para ...
# 8   Quem somos?\n\nSimplicidade é nosso nome e sob...
# 9   Resolver problemas complexos e explorar quais ...
# 10  Atividades:\n\nResponsável pelo desenvolviment...
# 11  #VemSerRCHLOVER\n\nA gente acredita que a moda...
# 12  A EY é líder global em serviços de Auditoria, ...
# 13  Deverá estar cursando: Estar cursando no mínim...
# 14  Liderança de equipe formada por Cientistas de ...
# 15  Formação Acadêmica:\nRedes de Computadores (Gr...
# ...

# %%
pd.DataFrame({'titulos':product_list})
# Out:
#                                               titulos
# 0                   Analista Ciência de Dados PL / SR
# 1                       Especialista Ciência de dados
# 2                          Consultor Ciência de Dados
# 3                    Estagiário(a) - Ciência de Dados
# 4              Coordenador Ciência de Dados | Pricing
# 5                         Gerente de Ciência de Dados
# 6   Especialista em Ciência de Dados - IT Data Ana...
# 7                    Estagiário(a) - Ciência de Dados
# 8             Pessoa Coordenadora de Ciência de Dados
# 9                                  Cientista de dados
# 10         Analista Ciência de Dados Sênior | Pricing
# 11                   Analista de Privacidade de Dados
# 12                          Cientista de dados Junior
# 13  Estagiário em Ciência de Dados e Sistemas de i...
# 14                        Gerente de ciência de dados
# 15                             TI - ANALISTA DE REDES
# ...

# %%
pd.DataFrame({'Titulos':product_list, 'Descricao':descr_list})
# Out:
#                                               Titulos  \
# 0                   Analista Ciência de Dados PL / SR
# 1                       Especialista Ciência de dados
# 2                          Consultor Ciência de Dados
# 3                    Estagiário(a) - Ciência de Dados
# 4              Coordenador Ciência de Dados | Pricing
# 5                         Gerente de Ciência de Dados
# 6   Especialista em Ciência de Dados - IT Data Ana...
# 7                    Estagiário(a) - Ciência de Dados
# 8             Pessoa Coordenadora de Ciência de Dados
# 9                                  Cientista de dados
# 10         Analista Ciência de Dados Sênior | Pricing
# 11                   Analista de Privacidade de Dados
# 12                          Cientista de dados Junior
# 13  Estagiário em Ciência de Dados e Sistemas de i...
# 14                        Gerente de ciência de dados
# 15                             TI - ANALISTA DE REDES
# ...
